# %%
 import numpy as np
import pandas as pd

# %% [markdown]
# # Creacion DataFrames

# %% [markdown]
# * Creo DF

# %%
#Creo la data JSON con features
data = {}

observaciones = range(0,5)
media = 0
  
peso = np.random.randint(45,80, 3)
talla = np.random.randint(160, 180, 3) / 100
calzado = np.random.randint(35,44,3 )

imc = peso / talla**2

data["masa"] = list(peso)
data["talla"] = list(talla)
data["calzado"] = list(calzado)
data["imc"] = list(imc)

data
# Out:
# {'masa': [78, 77, 45],
#  'talla': [1.78, 1.75, 1.62],
#  'calzado': [43, 42, 41],
#  'imc': [24.61810377477591, 25.142857142857142, 17.146776406035663]}

# %%
#Creo DF
df = pd.DataFrame(data)
df
# Out:
#    masa  talla  calzado        imc
# 0    78   1.78       43  24.618104
# 1    77   1.75       42  25.142857
# 2    45   1.62       41  17.146776

# %% [markdown]
# * Agregar una nuev feature, calcula de otras (indexadas)

# %%
#Una forma
df.imc = df.masa / (df.talla **2)
df
# Out:
#    masa  talla  calzado        imc
# 0    78   1.78       43  24.618104
# 1    77   1.75       42  25.142857
# 2    45   1.62       41  17.146776

# %% [markdown]
# * Una forma

# %%
df["imc"] = df["masa"] / (df["talla"] **2)
df
# Out:
#    masa  talla  calzado        imc
# 0    67   1.79       43  20.910708
# 1    45   1.73       35  15.035584
# 2    47   1.72       41  15.886966
