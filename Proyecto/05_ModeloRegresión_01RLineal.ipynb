# %%
# This is a python block

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sklearn.metrics as metrics

# %% [markdown]
# # Cargar data

# %% [markdown]
# - cargo

# %%
df_data = pd.read_csv('./dataset_clean.csv', index_col=[0])

# %% [markdown]
# # Preprocesamiento rápido

# %% [markdown]
# - Resuelvo problemas con descriptores que tienen infinitos

# %%
filter = df_data['Vacancy energy (log[eV/O atom])'] == -np.inf
df_data['Vacancy energy (log[eV/O atom])'][filter] = np.nan
# Out:
# /tmp/ipykernel_1511/1743523762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Vacancy energy (log[eV/O atom])'][filter] = np.nan

# %%
filter = df_data['Stability (log[eV/atom])'] == -np.inf
df_data['Stability (log[eV/atom])'][filter] = np.nan
# Out:
# /tmp/ipykernel_1511/1119673096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Stability (log[eV/atom])'][filter] = np.nan

# %% [markdown]
# - Elimino nulos sí o sí (la otra alternativa sería imputar)

# %%
df_data.isnull().sum()
# Out:
# Lowest distortion                     0
# A                                     0
# B                                     0
# Radius A [ang]                        0
# Radius B [ang]                        0
# Formation energy [eV/atom]            0
# Stability [eV/atom]                   0
# Volume per atom [A^3/atom]            0
# Band gap [eV]                         0
# a [ang]                               0
# Vacancy energy [eV/O atom]          349
# Stability (log[eV/atom])            290
# Vacancy energy (log[eV/O atom])    3169
# Magnetic moment (^2[mu_B])          947
# Valence B_1                           0
# Valence B_2                           0
# Valence B_3                           0
# Valence B_4                           0
# Valence B_5                           0
# Valence B_element not in BV           0
# Valence B_not balanced                0
# dtype: int64

# %%
df_data.drop('Vacancy energy (log[eV/O atom])', axis=1, inplace= True)

# %%
df_data.dropna(inplace=True)

# %% [markdown]
# # Split target y patrón

# %% [markdown]
# - Split

# %%
x = df_data.drop(['Lowest distortion', 'a [ang]'], axis=1)
y = df_data['a [ang]']

# %% [markdown]
# - Validación

# %%
print(x.shape)
print(y.shape)
# Out:
# (3720, 18)
# (3720,)

# %% [markdown]
# # Split train y test

# %% [markdown]
# - Split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12, shuffle = True)

# %% [markdown]
# - Validación

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2976, 18)
# (744, 18)

# %%
X_train.columns
# Out:
# Index(['A', 'B', 'Radius A [ang]', 'Radius B [ang]',
#        'Formation energy [eV/atom]', 'Stability [eV/atom]',
#        'Volume per atom [A^3/atom]', 'Band gap [eV]',
#        'Vacancy energy [eV/O atom]', 'Stability (log[eV/atom])',
#        'Magnetic moment (^2[mu_B])', 'Valence B_1', 'Valence B_2',
#        'Valence B_3', 'Valence B_4', 'Valence B_5',
#        'Valence B_element not in BV', 'Valence B_not balanced'],
#       dtype='object')

# %% [markdown]
# # Escalamiento/Normalización de los datos

# %% [markdown]
# - Instancio scaler para target y patron

# %%
x_st_scaler = StandardScaler() #Creo instancia del scaler
y_st_scaler = StandardScaler() #Creo instancia del scaler

# %% [markdown]
# - Escalo con fit sobre train, y trasnformo test

# %%
X_train = x_st_scaler.fit_transform(X_train) # escalo train
X_test = x_st_scaler.transform(X_test) #transformo test

# %%
y_train = y_st_scaler.fit_transform(y_train.values.reshape(-1,1)) # escalo train
y_test = y_st_scaler.transform(y_test.values.reshape(-1,1)) #transformo test

# %% [markdown]
# # Entrenamiento del modelo con Linear Regression

# %% [markdown]
# - Importo modelo de Sklearn

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# - Instancio modelo

# %%
model = LinearRegression()

# %% [markdown]
# - Entreno

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# - Predigo

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# - Evaluación rápida

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = metrics.mean_squared_error(y_test, y_pred, squared=False)

r2 = metrics.r2_score(y_test, y_pred)

# %%
print("mae: \t", mae.round(4))
print("mse: \t", mse.round(4))
print("rmse: \t", rmse.round(4))
print("r2: \t", r2.round(4))
# Out:
# mae: 	 0.4034
# mse: 	 0.2883
# rmse: 	 0.537
# r2: 	 0.7231

# %% [markdown]
# # Mejora del modelo y residuales

# %% [markdown]
# - Instalo rgressors para hacer un análisis más profundo de la regresión lineal

# %%
# !pip install --upgrade pip setuptools==57.5.0
# !pip install regressors
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.1.2)
# Requirement already satisfied: setuptools==57.5.0 in /root/venv/lib/python3.9/site-packages (57.5.0)
# Requirement already satisfied: regressors in /root/venv/lib/python3.9/site-packages (0.0.3)
# Requirement already satisfied: numpy>=1.6.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (1.23.4)
# Requirement already satisfied: scipy>=0.9 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (1.9.3)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (3.6.0)
# Requirement already satisfied: scikit-learn>=0.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (1.1.2)
# Requirement already satisfied: statsmodels>=0.6.1 in /root/venv/lib/python3.9/site-packages (from regressors) (0.14.0)
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (0.12.1)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from regressors) (1.2.5)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.17->regressors) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.17->regressors) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /root/venv/lib/python3.9/site-packages (from statsmodels>=0.6.1->regressors) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels>=0.6.1->regressors) (21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas->regressors) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->regressors) (2022.5)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->regressors) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->regressors) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->regressors) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->regressors) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->regressors) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->regressors) (3.0.9)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.6.1->regressors) (1.16.0)

# %% [markdown]
# - Imports el stats de regressors

# %%
from regressors import stats

# %% [markdown]
# ## Evaluación modelo 1

# %% [markdown]
# - saco intercepto y coeficientes

# %%
model.intercept_ = model.intercept_[0]
model.coef_ = model.coef_.reshape(-1)

# %% [markdown]
# - Stats summary

# %%
y_test = y_test.reshape(-1)

print("==========Summary==========")

# le paso modelo, datos de test y column names de los features
stats.summary(model, X_test, y_test, list(list(x)))

#el iintercepto esta muy elevdo, al igual que A,B, band gap, magnetic moment, y todas las valencias
# Out:
# ==========Summary==========
# Residuals:
#     Min      1Q  Median     3Q    Max
# -1.7979 -0.3161  0.0392 0.2949 1.9342
#
#
# Coefficients:
#                              Estimate     Std. Error  t value   p value
# _intercept                  -0.000000       0.019898  -0.0000  1.000000
# A                           -0.032370       0.020254  -1.5982  0.110422
# B                           -0.016238       0.020040  -0.8103  0.418046
# Radius A [ang]              -0.123499       0.026198  -4.7140  0.000003
# Radius B [ang]               0.164242       0.036253   4.5304  0.000007
# Formation energy [eV/atom]  -0.116035       0.030046  -3.8619  0.000122
# Stability [eV/atom]         -0.245772       0.035280  -6.9663  0.000000
# Volume per atom [A^3/atom]   0.249752       0.032978   7.5733  0.000000
# Band gap [eV]               -0.000259       0.024088  -0.0108  0.991419
# Vacancy energy [eV/O atom]  -0.200279       0.026494  -7.5595  0.000000
# Stability (log[eV/atom])    -0.513511       0.035257 -14.5647  0.000000
# Magnetic moment (^2[mu_B])  -0.013889       0.024331  -0.5708  0.568278
# Valence B_1                 -0.009926    7279.631874  -0.0000  0.999999
# Valence B_2                  0.004807   36011.867106   0.0000  1.000000
# Valence B_3                 -0.035444  161524.916989  -0.0000  1.000000
# Valence B_4                  0.019643  154535.183528   0.0000  1.000000
# Valence B_5                 -0.009901   45626.508625  -0.0000  1.000000
# Valence B_element not in BV  0.014430  191086.769170   0.0000  1.000000
# Valence B_not balanced       0.004879  215513.891184   0.0000  1.000000
# ---
# R-squared:  0.72310,    Adjusted R-squared:  0.71622
# F-statistic: 105.18 on 18 features

# %% [markdown]
# - Residuales (resta entre reales y predichos)

# %%
residuals = np.subtract(y_test, y_pred.reshape(-1))
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='-')
plt.show()

# %% [markdown]
# ## Evaluación modelo 2

# %% [markdown]
# - Copio el df original

# %%
df_second = df_data.copy()

# %% [markdown]
# - Hago nuevo modelo usando solo las comumnas de interes

# %%
df_second.columns
# Out:
# Index(['Lowest distortion', 'A', 'B', 'Radius A [ang]', 'Radius B [ang]',
#        'Formation energy [eV/atom]', 'Stability [eV/atom]',
#        'Volume per atom [A^3/atom]', 'Band gap [eV]', 'a [ang]',
#        'Vacancy energy [eV/O atom]', 'Stability (log[eV/atom])',
#        'Magnetic moment (^2[mu_B])', 'Valence B_1', 'Valence B_2',
#        'Valence B_3', 'Valence B_4', 'Valence B_5',
#        'Valence B_element not in BV', 'Valence B_not balanced'],
#       dtype='object')

# %%
X_cols = ['Radius A [ang]', 'Radius B [ang]', 'Formation energy [eV/atom]', 'Stability [eV/atom]',
        'Volume per atom [A^3/atom]', 'Vacancy energy [eV/O atom]', 'Stability (log[eV/atom])',]
y_col = ['a [ang]']

x = df_second[X_cols]
y = df_second[y_col]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12, shuffle = True)

x_st_scaler = StandardScaler() #Creo instancia del scaler
y_st_scaler = StandardScaler() #Creo instancia del scaler

X_train = x_st_scaler.fit_transform(X_train) # escalo train
X_test = x_st_scaler.transform(X_test) #transformo test
y_train = y_st_scaler.fit_transform(y_train.values.reshape(-1,1)) # escalo train
y_test = y_st_scaler.transform(y_test.values.reshape(-1,1)) #transformo test

model = LinearRegression(fit_intercept=False) #entreno SIN el intercepto
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

mse = metrics.mean_squared_error(y_test,y_pred)
r2 = metrics.r2_score(y_test, y_pred)

# %% [markdown]
# - Evaluacióon rápida

# %%
mse = metrics.mean_squared_error(y_test,y_pred)
r2 = metrics.r2_score(y_test, y_pred)

print("r2 ", r2.round(4))
print("mse: ", mse.round(4))
# Out:
# r2  0.7254
# mse:  0.286

# %% [markdown]
# - Stats

# %%
#model.intercept_ = model.intercept_[0]
model.coef_ = model.coef_.reshape(-1)

# %%
y_test = y_test.reshape(-1)

print("==========Summary==========")
stats.summary(model, X_test, y_test, X_cols)
# Out:
# ==========Summary==========
# Residuals:
#     Min      1Q  Median     3Q    Max
# -1.8346 -0.3176  0.0483 0.3012 1.8884
#
#
# Coefficients:
#                             Estimate  Std. Error  t value   p value
# _intercept                  0.000000    0.019715   0.0000  1.000000
# Radius A [ang]             -0.120430    0.024789  -4.8582  0.000001
# Radius B [ang]              0.162730    0.033688   4.8305  0.000002
# Formation energy [eV/atom] -0.105216    0.026246  -4.0088  0.000067
# Stability [eV/atom]        -0.263142    0.034307  -7.6702  0.000000
# Volume per atom [A^3/atom]  0.260160    0.030788   8.4500  0.000000
# Vacancy energy [eV/O atom] -0.198565    0.025043  -7.9291  0.000000
# Stability (log[eV/atom])   -0.506391    0.033167 -15.2678  0.000000
# ---
# R-squared:  0.72538,    Adjusted R-squared:  0.72276
# F-statistic: 277.72 on 7 features

# %%
residuals = np.subtract(y_test, y_pred.reshape(-1))
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='-')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a7ebb3ed-5c94-423a-a3b7-e9cd0209ff98' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
